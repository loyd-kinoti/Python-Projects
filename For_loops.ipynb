# %%
integer=[1,2,3,4,5,6]

# %%
for number in integer:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
type(integer)
# Out:
# tuple

# %%
for number in integer:
    print("yep")
# Out:
# yep
# yep
# yep
# yep
# yep
# yep

# %%
ice_cream_dict={"name":"Loyd Kinoti", "weekly intake": 5, "favorite icecream":["MCC","Chocolate"]}

# %%
'for cream in ice_cream_dict.values():
    print (cream)
# Out:
# Loyd Kinoti
# 5
# ['MCC', 'Chocolate']

# %%
for key,value in ice_cream_dict.items():
    print (key,"->",value)
# Out:
# name -> Loyd Kinoti
# weekly intake -> 5
# favorite icecream -> ['MCC', 'Chocolate']

# %%
#Nested For loops
flavors=["vanilla","chocolate","Cookie dough"]
toppings=["Hot fudge","Oreos","Marshmallows"]

# %%
for one in flavors:
    for two in toppings:
        print(one, "topped with", two)
# Out:
# vanilla topped with Hot fudge
# vanilla topped with Oreos
# vanilla topped with Marshmallows
# chocolate topped with Hot fudge
# chocolate topped with Oreos
# chocolate topped with Marshmallows
# Cookie dough topped with Hot fudge
# Cookie dough topped with Oreos
# Cookie dough topped with Marshmallows

# %%
# challenge
fruits=["apple","banana","cherry"]
for fruit in fruits:
    print (fruit)
# Out:
# apple
# banana
# cherry

# %%
fruits=["apple","banana","cherry"]
for fruit in fruits:
     if fruit == "banana":
        print (fruit)
        break
# Out:
# banana

# %%
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
    print(fruit)
    if fruit == "banana":
        break
# Out:
# apple
# banana
