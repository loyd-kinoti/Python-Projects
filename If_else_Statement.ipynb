# %%
if 10<24:
    print ("it worked")
# Out:
# it worked

# %%
if 10<24:
    print ("it worked")
else:
    print( "it didnt work")
# Out:
# it worked

# %%
if 26<24:
    print ("it worked")
elif 26<25:
    print ("finally1 here")
elif 26<22:
    print ("finally2 here")
elif 26<30:
    print ("finally3 here")
elif 27<26:
    print ("finally4 here")
elif 26<30:
    print ("finally5 here")
else:
    print( "it didnt work")
# Out:
# finally3 here

# %%
print ("it worked")if 26<24 else print( "it didnt work")
# Out:
# it didnt work

# %%
if 26<24:
    print ("it worked")
if 10<24:
    print ("it def worked")
elif 26<25:
    print ("finally1 here")
elif 26<22:
    print ("finally2 here")
elif 26<30:
    print ("finally3 here")
elif 27<26:
    print ("finally4 here")
elif 26<30:
    print ("finally5 here")
else:
    print( "it didnt work")
# Out:
# it def worked
