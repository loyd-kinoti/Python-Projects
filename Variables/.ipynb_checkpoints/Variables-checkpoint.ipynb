# %%
x=22
print (x)
# Out:
# 22

# %%
print (2*x)
# Out:
# 44

# %%
y="Mint Chocolate"
print(y)
# Out:
# Mint Chocolate

# %%
type (y)
type (x)
# Out:
# int

# %%
type (y)
# Out:
# str

# %%
x,y,z= "Chocolate","Vanila","Rock burn"
print (x)
print (y)
print (z)
# Out:
# Chocolate
# Vanila
# Rock burn

# %%
x=y=z="Bear"
print(x)
print(y)
print(z)
# Out:
# Bear
# Bear
# Bear

# %%
ice_cream=["Chocolate","Vanila","Rock burn"]
x,y,z=ice_cream
print(x)
print(y)
print(z)
# Out:
# Chocolate
# Vanila
# Rock burn

# %%
# Camel Case
# Test Variable Case
testVariableCase = "Vanilla Swirl"

# %%
# Pascal Case
# Test Variable Case
TestVariableCase = "Vanilla Swirl"

# %%
# snake case
# Test Variable Case
test_variable_case = "Vanilla Swirl"

# %%
x = "ice cream is my favourite" +"dessert"
print(x)
# Out:
# ice cream is my favouritedessert

# %%
x = "ice cream is my favourite" +"2"
print(x)
# Out:
# ice cream is my favourite2

# %%
x = "ice"
y = "cream "
z = "is my favourite" +" dessert"
print(x+y+z)
# Out:
# icecream is my favouritedessert
