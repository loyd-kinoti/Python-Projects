# %%
x=12.5
print (x)
# Out:
# 12.5

# %%
a= 'Hello World'
print (a[6])
# Out:
# W

# %%
a= 'Hello World'
print (a[-3])
# Out:
# r

# %%
a= 'Hello World'
print (a[:-3])
# Out:
# Hello Wo

# %%
a= 'Hello World'
print (a[1:-3])
# Out:
# ello Wo

# %%
#lists

# %%
(1,2,3,4)
# Out:
# (1, 2, 3, 4)

# %%
("cookie","Chapati","Doughnuts")
# Out:
# ('cookie', 'Chapati', 'Doughnuts')

# %%
icecream = ["cookie","Chapati","Doughnuts"]
icecream.append ("caramel")
icecream
# Out:
# ['cookie', 'Chapati', 'Doughnuts', 'caramel']

# %%
icecream[1]= ("cocktail")
icecream
# Out:
# ['cookie', 'cocktail', 'Doughnuts', 'caramel']

# %%
icecream = ["cookie","Chapati",["water","flour"],"Doughnuts"]
icecream [2][1]
# Out:
# 'flour'

# %%
chapati= ("water","flour")

icecream = ["cookie","Chapati",["water","flour"],"Doughnuts"]
icecream [1]
# Out:
# 'Chapati'

# %%
#tuple
tuple_scoop=(1,2,3,4,1,2,1)
tuple_scoop[2]
# Out:
# 3

# %%
#sets
daily_pint={1,2,3,4}
print (daily_pint)
# Out:
# {1, 2, 3, 4}

# %%
daily_pint_log={31,1,2,3,55,66,3,22,5}
print (daily_pint_log)
# Out:
# {1, 2, 3, 66, 5, 22, 55, 31}

# %%
wifes_daily_pint_log={1,2,4,6,55,6,33,55,33}

# %%
print(daily_pint_log|wifes_daily_pint_log)
# Out:
# {1, 2, 3, 66, 5, 33, 4, 6, 22, 55, 31}

# %%
print(daily_pint_log&wifes_daily_pint_log)
# Out:
# {1, 2, 55}

# %%
print(daily_pint_log-wifes_daily_pint_log)
# Out:
# {66, 3, 5, 22, 31}

# %%
print(daily_pint_log^wifes_daily_pint_log)
# Out:
# {66, 3, 4, 5, 6, 22, 31, 33}

# %%
#Dictionaries
#Key/Value Pair
dict_cream={"name":"Loyd Kinoti","weekly intake":5,"favourite icecreams":["MCC","caramel"]}

# %%
print(dict_cream)
# Out:
# {'name': 'Loyd Kinoti', 'weekly intake': 5, 'favourite icecreams': ['MCC', 'caramel']}

# %%
dict_cream.values ()
# Out:
# dict_values(['Loyd Kinoti', 5, ['MCC', 'caramel']])

# %%
dict_cream.keys()
# Out:
# dict_keys(['name', 'weekly intake', 'favourite icecreams'])

# %%
dict_cream.items()
# Out:
# dict_items([('name', 'Loyd Kinoti'), ('weekly intake', 5), ('favourite icecreams', ['MCC', 'caramel'])])

# %%
dict_cream["name"]
# Out:
# 'Loyd Kinoti'

# %%
dict_cream["name"]="Kelvin muriithi"
dict_cream.values()
# Out:
# dict_values(['Kelvin muriithi', 5, ['MCC', 'caramel']])
