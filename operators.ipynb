# %%
x =10
print (x)
# Out:
# 10

# %%
Ice_cream="I love ice scream"
"love" in Ice_cream
# Out:
# True

# %%
scoops=[1,3,5,8,6,3,5,6]
x = 3
x not in scoops
# Out:
# False

# %%
scoops=[1,3,5,8,6,3,5,6]
3 not in scoops
# Out:
# False
